# %%
import pandas as pd

clean_planet_df = pd.read_csv("working_data.csv", low_memory=False)
clean_planet_df.head()
# Out:
#    Unnamed: 0 PlanetIdentifier DiscoveryMethod  DiscoveryYear  Eccentricity  \
# 0           0      KOI-1843.03         transit         2012.0           NaN
# 1           1     Kepler-974 b         transit            NaN           NaN
# 2           2      KOI-1843.02         transit            NaN           NaN
# 3           3       Kepler-9 b         transit         2010.0        0.0626
# 4           4       Kepler-9 c         transit         2010.0        0.0684
#
#    HostStarMassSlrMass  HostStarMetallicity  HostStarRadiusSlrRad  \
# 0                 0.52                 0.07                  0.50
# 1                 0.52                 0.07                  0.50
# 2                 0.52                 0.07                  0.50
# 3                 1.07                 0.12                  1.02
# 4                 1.07                 0.12                  1.02
#
#    HostStarTempK    ListsPlanetIsOn      ...        RadiusJpt  \
# ...

# %%
planet_df = clean_planet_df.loc[clean_planet_df["HostStar"] == "Kepler-9", :]
planet_df
# Out:
#    Unnamed: 0 PlanetIdentifier DiscoveryMethod  DiscoveryYear  Eccentricity  \
# 3           3       Kepler-9 b         transit         2010.0        0.0626
# 4           4       Kepler-9 c         transit         2010.0        0.0684
# 5           5       Kepler-9 d         transit         2010.0           NaN
#
#    HostStarMassSlrMass  HostStarMetallicity  HostStarRadiusSlrRad  \
# 3                 1.07                 0.12                  1.02
# 4                 1.07                 0.12                  1.02
# 5                 1.07                 0.12                  1.02
#
#    HostStarTempK    ListsPlanetIsOn      ...        RadiusJpt  \
# 3         5777.0  Confirmed planets      ...            0.840
# 4         5777.0  Confirmed planets      ...            0.820
# 5         5777.0  Confirmed planets      ...            0.147
#
#    SemiMajorAxisAU  SurfaceTempK  TypeFlag  HostStar  HostStarLuminosity  \
# ...
